# %%
resp = """Let me answer your question about the strength of concrete. The strength of concrete is generally based on the test value of a concrete specimen that has been cured for 28 days. The strength of concrete is determined by the larger value between the design standard compressive strength () and the durability standard compressive strength () that reflects the durability design.

In order to find out the exact strength of concrete, it is necessary to approach it according to various variables.

In general concrete, the 28-day concrete strength is the standard.
The mixing strength is expressed as the compressive strength of a specimen that has been cured for (20±2)℃.
The concrete strength may vary depending on the working conditions or construction order of the structure.
The design standard for 28-day concrete strength may be specified differently for various construction projects. The strength of concrete should be determined based on the design standard compressive strength of the structure."""

# %%
chunk1 = """General Concrete Title: General 1.8 General information on chloride content and strength of concrete 1.8.1 Chloride content (1) The chloride content in concrete is expressed as the total amount of chloride ions contained in the concrete. (2) The chloride content in unhardened concrete shall, in principle, be 0.30㎏/㎥ or less as chloride ion amount (Cl-). (3) When tap water is used as mixing water and the amount of chloride ions contained in it is unclear, the amount of chloride ions supplied to the concrete from the mixing water may be assumed to be 250㎎/L. However, in case of test, that value shall be used. (4) When constructing structures such as reinforced concrete or post-tensioned prestressed concrete, or unreinforced concrete with reinforcement below the minimum reinforcement ratio, where there is no concern about external chloride ion intrusion, and where it is very difficult to obtain materials with low chloride content, the allowable upper limit of the total chloride content in the concrete may be set to 0.60 kg/㎥ after taking effective measures for rust prevention and obtaining approval from the responsible engineer. (5) The water-soluble chloride ion content of hardened concrete that has been cured for 28 days shall not exceed the values ​​in Table 1.9-3. (6) The provisions of this Article shall not apply to unreinforced concrete without reinforcement placed.

1.8.2 Strength (1) The strength of concrete is generally based on the test value of a concrete specimen that has been cured under standard conditions at 28 days. (2) In addition to compressive strength, the strength of concrete used in the design of concrete structures includes tensile strength, flexural strength, shear strength, bearing strength, and bond strength to steel. However, the compressive strength of concrete at 28 days is generally used as the standard for concrete structures. (3) The compressive strength test, tensile strength test, and flexural strength test of concrete shall be in accordance with KS F 2405, KS F 2423, and KS F 2408, respectively. In addition, the method of manufacturing test specimens shall be in accordance with KS F 2403."""

# %%
chunk2 = """General Concrete Title: Materials 2.2 Mixing 2.2.1 General (1) The mixing ratio of concrete shall be determined to have the required strength, durability, watertightness, crack resistance, and performance to protect reinforcing bars or steel. (2) The mixing ratio of concrete shall be determined in consideration of durability, and at this time, the design standard compressive strength and water-binding ratio shall be determined in accordance with 1.9.3(1). However, in the case of structures for which the exposure grade has not been determined, the mixing ratio shall be determined by applying the design standard compressive strength determined through structural calculation and the water-binding ratio specified in 2.2.3. (3) In order to have workability suitable for the work, the concrete mixing ratio shall be determined so that the concrete is sufficiently filled into every corner of the formwork, and the compaction work is easy and the material separation does not occur. 2.2.2 Mixing strength (1) In order for the compressive strength of concrete used in a structure to have the required strength, the mixing strength () must be determined during the concrete mixing design. The mixing strength () is expressed as the compressive strength of the test specimen cured at (20±2)℃, and the strength is based on the age based on the strength management. (2) The quality standard strength () is determined as the larger value between the design standard compressive strength () determined in the structural calculation and the durability standard compressive strength () reflecting the durability design, as in Equation (2.2-1). (MPa) (2.2-1) (3) Users of ready-mixed concrete must add the temperature-corrected strength () according to Equation (2.2-2) and order it from the manufacturer as the nominal strength (). (MPa) (2.2-2) Here, ; the temperature-corrected strength (MPa) is as in Table 2.2-1. (4) The mixing strength () should be determined as the larger value among the values ​​obtained by each of the two equations (①② and ①′②′) among equations (2.2-3) and (2.2-4) that classify the nominal strength () range based on 35 MPa. In the case of ≤ 35 MPa, (2.2-3) ①(MPa) ②(MPa)

＞ In the case of 35 MPa, (2.2-4) ①′(MPa) ②′(MPa) where, ; standard deviation of compressive strength (MPa)

(5) In the case of a field batch plant, the quality standard strength () that considers the temperature-compensated strength () can be used instead of the nominal strength () in (4).

Table 2.2-1 Correction values ​​for concrete strength according to temperature()

Type of binder Age (days) Expected average temperature range from concrete pouring date to age (°C) Expected average temperature range from concrete pouring date to age (°C).1 Expected average temperature range from concrete pouring date to age (°C).2
Ordinary Portland Cement Fly Ash Cement Type 1 Blast Furnace Slag Cement Type 1 28.0 18 or more 8 or more∼less than 18 4 or more∼less than 8
Ordinary Portland Cement Fly Ash Cement Type 1 Blast Furnace Slag Cement Type 2 42.0 12 or more 4 or more∼less than 12 -
Ordinary Portland Cement Fly Ash Cement Type 1 Blast Furnace Slag Cement Type 3 56.0 7 or more 4 or more∼less than 7 -
Fly Ash Cement Type 2 28.0 18 or more 10 or more∼less than 18 4 or more∼less than 10
Fly Ash cement type 3 42.0 13 or more 5 or more to less than 13 4 or more to less than 5
Fly ash cement type 4 56.0 8 or more 4 or more to less than 8 -
Blast furnace slag cement type 2 28.0 18 or more 13 or more to less than 18 4 or more to less than 13
Blast furnace slag cement type 3 42.0 14 or more 10 or more to less than 14 4 or more to less than 10
Blast furnace slag cement type 4 56.0 10 or more 5 or more to less than 10 4 or more to less than 5
Correction value of concrete strength according to temperature Tn (MPa) 0 3 6
(6) The standard deviation of concrete compressive strength is determined in principle from test results of concrete actually used more than 30 times. However, if the number of compressive strength tests is 29 or less and 15 or more, the standard deviation calculated from it can be used as the standard deviation by multiplying the correction factor in Table 2.2-2."""

# %%
chunk3 = """High-strength concrete Title: Materials 2.2 Mixing 2.2.1 Mixing (1) The mixing strength of high-strength concrete shall be determined in accordance with the provisions of KCS 14 20 10 (2.2.2). (2) The determination of the water-binder ratio shall be based on the following: ① The water-binder ratio of high-strength concrete shall be determined in consideration of the required strength and durability. ② The relationship between the water-binder ratio and the concrete strength shall be obtained from the test mixing ratio for concrete that obtains the required slump value or slump flow, and required air content using materials that are almost identical to those of the concrete actually used. ③ The water-binder ratio corresponding to the mixing strength shall be determined using the relationship derived from the test, and in this case, the water-binder ratio shall be determined on the safe side considering the reliability of the relationship. (3) The unit cement quantity shall be determined by the test to be as small as possible within the range where the required workability and strength can be obtained. (4) The unit water quantity shall be as small as possible within the range where the required workability can be obtained. (5) The fine aggregate ratio shall be determined by test to obtain the required workability and shall be as small as possible. (6) The unit amount of high-performance water reducing agent shall be determined by test to obtain the required strength and workability suitable for the work. (7) The slump shall be as small as possible within the workable range, and in the case of fluidized concrete, the target value of the slump flow shall be determined as 500, 600, and 700 mm according to the working conditions of the structure for the design standard compressive strength of 40 MPa or more and 60 MPa or less, and in the case of high-strength concrete above that, the instructions of the responsible engineer shall be followed. (8) As a rule, air entrainment agents shall not be used except in cases where weather changes are severe or measures against freezing and thawing are required.

2.2.2 Mixing (1) Mixing shall be done with a high-performance mixer. (2) The order of adding materials to the mixer shall be approved by the responsible engineer. The order of adding materials shall be determined so that the properties of the manufactured concrete are most suitable for the structure to be used. (3) The mixing time is determined by test in principle.

2.3 Material quality control (1) The quality inspection of high-strength concrete is according to Table 2.3-1. Table 2.3-1 Quality inspection of high-strength concrete

Type Item Test and inspection method Period and number of times Judgment criteria
Mixing Compressive strength KS F 2405 ∙Acceptance time∙Once/day or once every 120 m3 depending on the importance of the structure and the scale of the construction KCS 14 20 10 (Table 3.5-3)
Flowability Slump or slump flow KS F 2402KS F 2594orKCI-CT103 Same as ∙Slump: Set value ±25 mm (if less than 180 mm) Set value ±15 mm (if over 180 mm)∙Slump flow: Set value ±50 mm"""

# %%
chunk4 = """General Concrete 3.5.5.7 If the test results show that the strength of the concrete is low (1) If the results of the compression test of individual test specimens cured in the laboratory do not satisfy the provisions of Table 3.5-3 or if defects are found in the test results of test specimens cured in the field, the load-bearing capacity of the structure must be sufficiently reviewed and appropriate measures must be taken. (2) If the results of the compressive strength test of concrete do not satisfy the provisions, the suitability of the sample and the suitability of the testing equipment or testing method must be reviewed and evaluated excluding any inappropriate cases. (3) If the strength is judged to be insufficient as a result of the above (2), the extension of the management age must be considered. (4) If the strength is judged to be insufficient as a result of the above (2) and the extension of the management age is not possible, a non-destructive test shall be conducted in accordance with 3.5.5.5. If the non-destructive test results also fail, a core shall be collected from the problematic area and a test of the compressive strength of the core shall be conducted in accordance with KS F 2422. The test results of core strength are judged to be suitable if the average value exceeds 85% and each value exceeds 75%. (5) If the test results of (4) above show partial defects, the relevant part shall be reinforced or reconstructed, and if the overall defects are found, a load test shall be conducted in accordance with 3.5.5.8.

3.5.5.8 Performance test of structures by load test (1) If it is thought that the concrete has been subjected to freezing during construction, if it is judged that there is a problem with the strength based on the results of the concrete compressive strength test taken at the site during construction, or if there is any other reasonable doubt about the safety of the structure during construction, etc., if the responsible engineer deems it necessary, a load test shall be conducted. (2) If the performance of the structure is confirmed by a load test, the load test method shall be determined to be appropriate for the purpose. In this case, the loading method, load size, etc. shall be determined so as not to have a dangerous effect on the structure. (3) During and after loading, it shall be checked whether the deflection, strain, etc. of the structure are abnormal compared to the values ​​considered in the design. (4) Matters related to the load test, such as the load test method, load criteria, allowable criteria, and allowable bearing capacity, shall be governed by KDS 14 20 90. (5) If it is determined through the test results that there is a problem with the bearing capacity or durability of the structure, appropriate measures, such as reinforcing the structure, shall be taken according to the instructions of the responsible engineer."""

# %%
# !pip install -U sentence-transformers
# Out:
# ...
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 3.2.0
#     Uninstalling sentence-transformers-3.2.0:
#       Successfully uninstalled sentence-transformers-3.2.0
# ...

# %%
from sentence_transformers import SentenceTransformer, util 
sentences = ["In general concrete, the 28-day concrete strength is the standard." , "1.8.2 Strength (1) The strength of concrete is generally based on the test value of a concrete specimen that has been cured under standard conditions at 28 days."]

model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

#Compute embedding for both lists
embedding_1= model.encode(sentences[0], convert_to_tensor=True)
embedding_2 = model.encode(sentences[1], convert_to_tensor=True)

util.pytorch_cos_sim(embedding_1, embedding_2) 
## tensor([[0.6003]])
# Out:
# tensor([[0.8013]], device='mps:0')

# %%
import re

def split_into_sentences(paragraph):
    # Regular expression pattern
    sentence_endings = r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?|\!)\s'
    sentences = re.split(sentence_endings, paragraph)    
    return sentences

paragraph = resp
sentences = split_into_sentences(paragraph)
print(sentences)
# Out:
# ['Let me answer your question about the strength of concrete.', 'The strength of concrete is generally based on the test value of a concrete specimen that has been cured for 28 days.', 'The strength of concrete is determined by the larger value between the design standard compressive strength () and the durability standard compressive strength () that reflects the durability design.', '\nIn order to find out the exact strength of concrete, it is necessary to approach it according to various variables.', '\nIn general concrete, the 28-day concrete strength is the standard.', 'The mixing strength is expressed as the compressive strength of a specimen that has been cured for (20±2)℃.', 'The concrete strength may vary depending on the working conditions or construction order of the structure.', 'The design standard for 28-day concrete strength may be specified differently for various construction projects.', 'The strength of concrete should be determined based on the design standard comp
# ...

# %%
resp_lines = split_into_sentences(resp)
chunk_lines = split_into_sentences(chunk1)

# %%
chunk_lines , resp_lines
# Out:
# (['General Concrete Title: General 1.8 General information on chloride content and strength of concrete 1.8.1 Chloride content (1) The chloride content in concrete is expressed as the total amount of chloride ions contained in the concrete.',
#   '(2) The chloride content in unhardened concrete shall, in principle, be 0.30㎏/㎥ or less as chloride ion amount (Cl-).',
#   '(3) When tap water is used as mixing water and the amount of chloride ions contained in it is unclear, the amount of chloride ions supplied to the concrete from the mixing water may be assumed to be 250㎎/L.',
#   'However, in case of test, that value shall be used.',
# ...

# %%
for one_line in resp_lines :
    for another_line in chunk_lines :
        e1 = model.encode(one_line, convert_to_tensor=True) 
        e2 = model.encode(another_line, convert_to_tensor=True) 
        score = util.pytorch_cos_sim(e1, e2) 
        print(one_line)
        print("\n")
        print(another_line)
        print("score" , score)
        print("-------------------------------------------")
        print("\n")
# Out:
# Let me answer your question about the strength of concrete.
#
#
# General Concrete Title: General 1.8 General information on chloride content and strength of concrete 1.8.1 Chloride content (1) The chloride content in concrete is expressed as the total amount of chloride ions contained in the concrete.
# score tensor([[0.5533]], device='mps:0')
# -------------------------------------------
#
#
# Let me answer your question about the strength of concrete.
#
#
# (2) The chloride content in unhardened concrete shall, in principle, be 0.30㎏/㎥ or less as chloride ion amount (Cl-).
# score tensor([[0.5913]], device='mps:0')
# -------------------------------------------
#
#
# Let me answer your question about the strength of concrete.
#
#
# (3) When tap water is used as mixing water and the amount of chloride ions contained in it is unclear, the amount of chloride ions supplied to the concrete from the mixing water may be assumed to be 250㎎/L.
# score tensor([[0.3542]], device='mps:0')
# ...
